# %%
import sys, os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from ml_lib import LinearRegression as CustomLR, RidgeRegression as CustomL2R, LassoRegression as CustomL1R
import numpy as np
import matplotlib.pyplot as plt

# %%
X = 2 * np.random.rand(50, 1)
y = 2 * X + 3 + np.random.rand(50, 1)

# %%
lr = CustomLR(fit_intercept=True)
lr.fit(X,y)
pred = lr.predict(X)
print(lr.get_params())
# Out:
# {'fit_intercept': True, 'method': 'normal', 'learning_rate': 0.01, 'n_iterations': 1000, 'tol': 1e-06, 'w': array([1.98097901]), 'b': 3.57518238897956}

# %%
plt.plot(X, pred, 'r-')
plt.plot(X, y, 'b.')

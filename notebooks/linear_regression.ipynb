# %%
import sys, os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from ml_lib import (LinearRegression as CustomLR,
                    RidgeRegression as CustomL2R, 
                    LassoRegression as CustomL1R,
                    ElasticNetRegression as CustomENR) 
import numpy as np
import matplotlib.pyplot as plt

# %%
X = 2 * np.random.rand(50, 1)
y = 2 * X + 3 + np.random.rand(50,1)

# %%
lr = CustomENR()
lr.fit(X,y)
pred = lr.predict(X)
print(lr.get_params)
# Out:
# {'fit_intercept': True, 'optimizer': 'normal', 'learning_rate': 0.01, 'max_iter': 1000, 'tol': 1e-06, 'w': array([2.05275816]), 'b': 3.4366242167822234, 'alpha': 0.1, 'r': 0.5}

# %%
plt.plot(X, pred, 'r-')
plt.plot(X, y, 'b.')
plt.title("method: gradient")
# Out:
# Text(0.5, 1.0, 'method: gradient')

# %%
from mpl_toolkits.mplot3d import Axes3D

X = 2 * np.random.rand(100, 2)
y = 2 * X[:, 0] + X[:, 1] + 3 + 0.5 * np.random.randn(100)

lr.fit(X, y)

x0 = np.linspace(X[:, 0].min(), X[:, 0].max(), 30)
x1 = np.linspace(X[:, 1].min(), X[:, 1].max(), 30)
x0_grid, x1_grid = np.meshgrid(x0, x1)
X_grid = np.c_[x0_grid.ravel(), x1_grid.ravel()]
y_pred = lr.predict(X_grid).reshape(x0_grid.shape)

fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")
ax.scatter(X[:, 0], X[:, 1], y, color="blue", label="Data")
ax.plot_surface(x0_grid, x1_grid, y_pred, color="red", alpha=0.5)
ax.set_xlabel("X0")
ax.set_ylabel("X1")
ax.set_zlabel("y")
plt.show()

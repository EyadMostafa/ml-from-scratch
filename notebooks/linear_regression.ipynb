# %%
import sys, os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from ml_lib import (LinearRegression as CustomLR,
                    RidgeRegression as CustomL2R, 
                    LassoRegression as CustomL1R,
                    ElasticNetRegression as CustomENR) 
import numpy as np
import matplotlib.pyplot as plt

# %%
X = 2 * np.random.rand(50, 1)
y = 2 * X + 3 + np.random.rand(50, 1)

# %%
lr = CustomENR(optimizer='gd')
lr.fit(X,y)
pred = lr.predict(X)
print(lr.get_params())
# Out:
# {'fit_intercept': True, 'optimizer': 'gd', 'learning_rate': 0.01, 'max_iter': 1000, 'tol': 1e-06, 'w': array([1.90823047]), 'b': 3.5823009934497723, 'alpha': 0.1, 'r': 0.5}

# %%
plt.plot(X, pred, 'r-')
plt.plot(X, y, 'b.')
plt.title("method: gradient")
# Out:
# Text(0.5, 1.0, 'method: gradient')
